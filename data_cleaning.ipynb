# %%
# imports library 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
file_path ='../Carbon_emission_project/Data_files/energy_consumption.csv'
df_1= pd.read_csv(file_path, skiprows=2, encoding='unicode_escape')
df_1.head()
# Out:
#              Exajoules   1965   1966   1967   1968   1969   1970   1971  \
# 0                  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1               Canada   5.00   5.32   5.57   5.92   6.28   6.73   6.94
# 2               Mexico   1.06   1.12   1.14   1.24   1.36   1.45   1.53
# 3                   US  51.98  54.89  56.80  60.19  63.30  65.54  66.92
# 4  Total North America  58.04  61.33  63.51  67.36  70.95  73.72  75.39
#
#     1972   1973  ...    2016    2017    2018    2019    2020    2021    2022  \
# 0    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   7.47   8.11  ...   14.32   14.54   14.67   14.59   13.71   13.84   14.14
# 2   1.69   1.82  ...    8.11    8.26    8.16    8.06    7.43    7.99    8.73
# 3  70.25  73.22  ...   92.60   92.95   96.35   95.67   88.57   93.40   95.91
# 4  79.41  83.16  ...  115.04  115.76  119.18  118.32  109.71  115.23  118.78
#
#   2022.1 2012-22 2022.2
# 0    NaN     NaN    NaN
# ...

# %%
df_1.shape
# Out:
# (127, 62)

# %%
df_1.count()
# Out:
# Exajoules    110
# 1965         103
# 1966         103
# 1967         103
# 1968         103
#             ...
# 2021         103
# 2022         103
# 2022.1       103
# 2012-22      103
# 2022.2       103
# Length: 62, dtype: int64

# %%
df_1.isnull().sum()
# Out:
# Exajoules    17
# 1965         24
# 1966         24
# 1967         24
# 1968         24
#              ..
# 2021         24
# 2022         24
# 2022.1       24
# 2012-22      24
# 2022.2       24
# Length: 62, dtype: int64

# %%
df_1.dropna(inplace=True)

# %%
df_1.count()
# Out:
# Exajoules    103
# 1965         103
# 1966         103
# 1967         103
# 1968         103
#             ...
# 2021         103
# 2022         103
# 2022.1       103
# 2012-22      103
# 2022.2       103
# Length: 62, dtype: int64

# %%
df_1.isnull().sum()
# Out:
# Exajoules    0
# 1965         0
# 1966         0
# 1967         0
# 1968         0
#             ..
# 2021         0
# 2022         0
# 2022.1       0
# 2012-22      0
# 2022.2       0
# Length: 62, dtype: int64

# %%
df_1.head()
# Out:
#              Exajoules   1965   1966   1967   1968   1969   1970   1971  \
# 1               Canada   5.00   5.32   5.57   5.92   6.28   6.73   6.94
# 2               Mexico   1.06   1.12   1.14   1.24   1.36   1.45   1.53
# 3                   US  51.98  54.89  56.80  60.19  63.30  65.54  66.92
# 4  Total North America  58.04  61.33  63.51  67.36  70.95  73.72  75.39
# 6            Argentina   1.18   1.22   1.26   1.30   1.34   1.27   1.35
#
#     1972   1973  ...    2016    2017    2018    2019    2020    2021    2022  \
# 1   7.47   8.11  ...   14.32   14.54   14.67   14.59   13.71   13.84   14.14
# 2   1.69   1.82  ...    8.11    8.26    8.16    8.06    7.43    7.99    8.73
# 3  70.25  73.22  ...   92.60   92.95   96.35   95.67   88.57   93.40   95.91
# 4  79.41  83.16  ...  115.04  115.76  119.18  118.32  109.71  115.23  118.78
# 6   1.37   1.43  ...    3.57    3.57    3.54    3.34    3.13    3.48    3.60
#
#   2022.1 2012-22 2022.2
# 1   2.2%    0.1%   2.3%
# ...

# %%
df_1.rename(columns={'Exajoules':'Country'}, inplace=True)
df_1.head(15)
# Out:
#                 Country   1965   1966   1967   1968   1969   1970   1971  \
# 1                Canada   5.00   5.32   5.57   5.92   6.28   6.73   6.94
# 2                Mexico   1.06   1.12   1.14   1.24   1.36   1.45   1.53
# 3                    US  51.98  54.89  56.80  60.19  63.30  65.54  66.92
# 4   Total North America  58.04  61.33  63.51  67.36  70.95  73.72  75.39
# 6             Argentina   1.18   1.22   1.26   1.30   1.34   1.27   1.35
# 7                Brazil   0.99   1.08   1.11   1.27   1.39   1.63   1.82
# 8                 Chile   0.26   0.28   0.29   0.28   0.31   0.32   0.35
# 9              Colombia   0.35   0.40   0.42   0.43   0.44   0.48   0.48
# 10              Ecuador   0.03   0.03   0.04   0.04   0.04   0.05   0.06
# 11                 Peru   0.20   0.24   0.25   0.25   0.25   0.26   0.27
# 12    Trinidad & Tobago   0.12   0.13   0.14   0.14   0.15   0.16   0.16
# 13            Venezuela   0.69   0.70   0.73   0.79   0.80   0.81   0.82
# ...

# %%
df_1 = df_1[~df_1['Country'].str.contains('Total|total', case=False, na=False)]

# %%
df_1.head(30)
# Out:
#                 Country   1965   1966   1967   1968   1969   1970   1971  \
# 1                Canada   5.00   5.32   5.57   5.92   6.28   6.73   6.94
# 2                Mexico   1.06   1.12   1.14   1.24   1.36   1.45   1.53
# 3                    US  51.98  54.89  56.80  60.19  63.30  65.54  66.92
# 6             Argentina   1.18   1.22   1.26   1.30   1.34   1.27   1.35
# 7                Brazil   0.99   1.08   1.11   1.27   1.39   1.63   1.82
# 8                 Chile   0.26   0.28   0.29   0.28   0.31   0.32   0.35
# 9              Colombia   0.35   0.40   0.42   0.43   0.44   0.48   0.48
# 10              Ecuador   0.03   0.03   0.04   0.04   0.04   0.05   0.06
# 11                 Peru   0.20   0.24   0.25   0.25   0.25   0.26   0.27
# 12    Trinidad & Tobago   0.12   0.13   0.14   0.14   0.15   0.16   0.16
# 13            Venezuela   0.69   0.70   0.73   0.79   0.80   0.81   0.82
# 14      Central America   0.16   0.16   0.17   0.18   0.19   0.20   0.20
# ...

# %%
df_1 = df_1[~df_1.apply(lambda row: row.astype(str).str.contains('-').any(), axis=1)]

# %%
#df_1 = df_1[~df_1.apply(lambda row: row.astype(str).str.contains('^').any(), axis=1)]

# %%
df_1.replace('^', 0, inplace=True)

# %%
df_1.replace('?', 0, inplace=True)

# %%
df_1.tail(30)
# Out:
#                    Country    1965    1966    1967    1968    1969    1970  \
# 14         Central America    0.16    0.16    0.17    0.18    0.19    0.20
# 16     Other South America    0.15    0.16    0.16    0.17    0.18    0.19
# 21                Bulgaria    0.43    0.46    0.54    0.60    0.67    0.75
# 23                  Cyprus    0.02    0.02    0.02    0.02    0.03    0.03
# 32                 Iceland    0.03    0.03    0.03    0.03    0.03    0.04
# 33                 Ireland    0.24    0.27    0.30    0.34    0.35    0.27
# 49                  Turkey    0.33    0.38    0.39    0.46    0.50    0.53
# 65                    Iran    0.35    0.38    0.42    0.46    0.51    0.60
# 66                    Iraq    0.08    0.09    0.09    0.10    0.11    0.14
# 67                  Israel    0.15    0.15    0.19    0.19    0.21    0.23
# 68                  Kuwait    0.29    0.30    0.30    0.32    0.33    0.26
# ...

# %%
last_two_indices = df_1.index[-2:]
df_1.drop(last_two_indices, inplace=True)

# %%
df_1.drop(index=1, inplace=True)

# %%
df_1.to_csv('../Carbon_emission_project/Data_files/clean_energy_consumption.csv', index=False)
